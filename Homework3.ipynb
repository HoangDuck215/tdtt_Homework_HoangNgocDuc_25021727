# %%
#bài 1
x = input()
reverse_x = "".join(reversed(x))
print(reverse_x)
# Out:
# due
# eud

# %%
#bài 2
a = int(input("Enter a: "))
b = int(input("Enter b: "))
a = a^b
b = b^a
a = a^b
print(a, b)

# %%
#bài 3
x = int(input("Enter x: "))
if x & (x-1) ==0:
    print("True")
else:
    print("False")

# %%
#bài 4
m = int(input("Enter m: "))
n = int(input("Enter n: "))
print(m // n)

# %%
#bài 5
m = int(input("Enter m: "))
n = int(input("Enter n: "))
print(m // n +1)

# %%
#bài 6
x = int(input("Enter x: "))
if x % 2 == 0:
    print("Even")
else:
    print("Odd")

# %%
#bài 7
a = int(input("Enter a: "))
b = int(input("Enter b: "))
if a < 0 and b <0:
    print("Yes")
else:
    print("No")

# %%
#bài 8
a = input("Enter a:")
b = input("Enter b:")
if len(a) > len(b):
    print("True")
else:
    print("False")

# %%
#bài 9
a = int(input("Enter a: "))
b = int(input("Enter b: "))
c = int(input("Enter c: "))
if a + b > c and a + c > b and b + c > a:
    print("Yes")
else:
    print("No")

# %%
#bài 10
n = int(input("Enter n: "))
lst = list(map(int, input("Enter lst:").split()))
max = lst[0]
for i in range(n):
    if lst[i] > max:
         print(lst[i])

# %%
#bài 11
a = int(input("Enter a: "))
b = int(input("Enter b: "))
c = int(input("Enter c: "))
if a + b >c and a + c > b and b + c >a:
    if a == b == c:
        print("Tam giác đều")
    elif a == b or a == c or b == c:
        print("Tam giác cân")
    else:
        print("Tam giác thường")
else:
    print("Không phải tam giác")

# %%
#bài 12
a = int(input("Enter a: "))
if a % 4 ==0 and a % 100 !=0 or a % 400 ==0:
    print("Yes")
else:
    print("No")

# %%
#bài 13
x = int(input("Enter x: "))
if x >= 0 and x <=50:
    print(x*1500)
elif x >=51 and x <=100:
    print(50*1500 + (x-50)*2000)
elif x>=101:
    print(50*1500 + 50*2000 + (x-100)*3000)

# %%
#bài 14
a = int(input("Enter a: "))
b = int(input("Enter b: "))
if a == 0 and b == 0:
    print("Vo so nghiem")
elif a == 0:
    print("Vo nghiem")
else:
    print("nghiem phuong trinh la", round(-b/a,2))

# %%
#bài 15
x = float(input("Enter x: "))
if x >=8.0:
    print("Giỏi")
elif x >=6.5:
    print("Khá")
elif x>=5.0:
    print("Trung bình")
else:
    print("Yếu")

# %%
#bài 16
a = float(input("Enter a: "))
if a > 0:
    if a != int(a):
        round_up = int(a) + 1
    else:
        round_up = int(a)
else:
    round_up = int(a)
if a>0:
    if a!=int(a):
        round_down = int(a)
    else:
        round_down = int(a)
else:
    round_down = int(a)-1
if a>0:
    round_nearest = int(a+0.5)
else:
    round_nearest = int(a-0.5)
print(round_up, round_down, round_nearest)
